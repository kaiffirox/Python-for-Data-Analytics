# %% [markdown]
# #***22_NumPy***

# %%
# create a list of 1,000,000 salaries ranging from 50,000 to 150,000
import random

salary_list = [random.randint(50000, 100000)  for _ in range(10_000_000)]

# %%
len(salary_list)
# Out:
# 10000000

# %%
import statistics

# %%
# %%timeit

statistics.mean(salary_list)
# Out:
# 3.03 s ± 432 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit
np.mean(salary_list)
# Out:
# 629 ms ± 11.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# Job Titles
job_titles = np.array(['Data Analyst', 'Data Scientist', 'Data Engineer', 'Machine Learning Engineer'])

# Base Salaries
base_salaries = np.array([60000, 80000, 90000, 100000])

# Bonus rate
bonus_rates = np.array([0.1, 0.15, 0.2, 0.25])

# %%
total_salaries = base_salaries + (base_salaries * bonus_rates)

total_salaries
# Out:
# array([ 66000.,  92000., 108000., 125000.])

# %%
total_salaries1 = base_salaries * (1 + bonus_rates)

total_salaries1
# Out:
# array([ 66000.,  92000., 108000., 125000.])
